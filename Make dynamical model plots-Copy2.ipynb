# %%
from plot_util import *

# %%
savefig = False

# %%
ax, fig = plot_residual('jampy', 'ifu', 'constant', False, 'powerlaw', burnin=-2);

ax.set_xticks([])
ax.set_yticks([])

ax.set_title('')

if savefig:
    fig.savefig('/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/jampy_constant_elliptical.pdf', 
                bbox_inches='tight'
               )
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# reduced chi^2: 1.04
# /Users/ajshajib/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:335: RuntimeWarning: invalid value encountered in true_divide
#   im = ax.matshow((data_v_rms - model_v_rms) / noise_v_rms,

# %%
plot_dist(['jampy', 'jampy', 'jampy'], 
          ['ifu', 'ifu', 'ifu'], 
          ['free_step', 'step', 'constant'], 
          [False]*3, 
          ['powerlaw']*3, 
          burnin=-50, 
          legend_labels=[r'stepwise constant $\beta$ with free breakpoint', 
                         r'stepwise constant $\beta$', 
                         r'constant $\beta$'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}', 
                           '(\\sigma_{\\theta}/\\sigma_{r})_{\\rm outer}', "r_{\\rm break}\ ( '' )"],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/pl_axisymmetric_jam.pdf',
          font_scale=1.7
         )
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# WARNING:root:auto bandwidth for ani_param_3 very small or failed (h=0.0005280651181611414,N_eff=160.4274518824229). Using fallback (h=0.00102159091996942)
# WARNING:root:fine_bins not large enough to well sample smoothing scale - ani_param_3

# %%
plot_dist(['jampy'], 
          ['ifu'], 
          ['constant'], 
          [False], 
          ['composite'], 
          burnin=-50, 
          legend_labels=[r'composite mass model with constant $\beta$'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_axisymmetric_jam.pdf',
          font_scale=1.7
         )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 plot_dist(['jampy'],
#       2           ['ifu'],
#       3           ['constant'],
#       4           [False],
#       5           ['composite'],
#       6           burnin=-50,
#       7           legend_labels=[r'composite mass model with constant $\beta$'],
#       8           ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
#       9           #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_axisymmetric_jam.pdf',
#      10           font_scale=1.7
#      11          )
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:250, in plot_dist(softwares, aperture_types, anisotropy_models, is_sphericals, lens_model_types, burnin, legend_labels, save_fig, ani_param_latex, font_scale, select_indices)
#     246 mc_samples_list = []
#     248 for s, a, ani, sph, model in zip(softwares, aperture_types,
#     249                                  anisotropy_models, is_sphericals, lens_model_types):
# --> 250     mc_samples_list.append(get_getdist_samples(s, a, ani, sph, model, burnin=burnin,
#     251                                                latex_labels=latex_labels, select_indices=select_indices))
#     253 g = plots.getSubplotPlotter(subplot_size=2.2)
#     254 g.settings.lw_contour = 1.
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:204, in get_getdist_samples(software, aperture_type, anisotropy_model, is_spherical, lens_model_type, burnin, latex_labels, select_indices)
#     201     if latex_labels is None:
#     202         latex_labels = latex_labels_composite
# --> 204 chain = get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#     206 chain = chain[:, burnin:, :].reshape((-1, chain.shape[-1]))
#     207 if lens_model_type == 'powerlaw':
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:78, in get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#      74 def get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type='powerlaw'):
#      75     """
#      76     Get dynamics chain in right shape.
#      77     """
# ---> 78     samples_mcmc = np.loadtxt(
#      79         '../dynamics_chains/kcwi_dynamics_chain_{}_{}_{}_{}_{}_nl.txt'.format(
#      80             software, aperture_type, anisotropy_model, str(is_spherical), lens_model_type
#      81         )
#      82     )
#      84     n_params = samples_mcmc.shape[1]
#      86     n_walkers = walker_ratio * n_params
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#    1044     line_iter = iter(fh)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../dynamics_chains/kcwi_dynamics_chain_jampy_ifu_constant_False_composite_nl.txt not found.

# %%
plot_dist(['jampy']*2, 
          ['ifu']*2, 
          ['constant']*2, 
          [False]*2, 
          ['powerlaw', 'composite'], 
          burnin=-50, 
          legend_labels=[r'power-law mass model', r'composite mass model'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_vs_pl_axisymmetric_jam.pdf',
          font_scale=1.2,
          select_indices=[-4, -2, -1]
         )
# Out:
# (2400, 8) 8
# Removed no burn in
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 plot_dist(['jampy']*2,
#       2           ['ifu']*2,
#       3           ['constant']*2,
#       4           [False]*2,
#       5           ['powerlaw', 'composite'],
#       6           burnin=-50,
#       7           legend_labels=[r'power-law mass model', r'composite mass model'],
#       8           ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
#       9           #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_vs_pl_axisymmetric_jam.pdf',
#      10           font_scale=1.2,
#      11           select_indices=[-4, -2, -1]
#      12          )
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:250, in plot_dist(softwares, aperture_types, anisotropy_models, is_sphericals, lens_model_types, burnin, legend_labels, save_fig, ani_param_latex, font_scale, select_indices)
#     246 mc_samples_list = []
#     248 for s, a, ani, sph, model in zip(softwares, aperture_types,
#     249                                  anisotropy_models, is_sphericals, lens_model_types):
# --> 250     mc_samples_list.append(get_getdist_samples(s, a, ani, sph, model, burnin=burnin,
#     251                                                latex_labels=latex_labels, select_indices=select_indices))
#     253 g = plots.getSubplotPlotter(subplot_size=2.2)
#     254 g.settings.lw_contour = 1.
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:204, in get_getdist_samples(software, aperture_type, anisotropy_model, is_spherical, lens_model_type, burnin, latex_labels, select_indices)
#     201     if latex_labels is None:
#     202         latex_labels = latex_labels_composite
# --> 204 chain = get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#     206 chain = chain[:, burnin:, :].reshape((-1, chain.shape[-1]))
#     207 if lens_model_type == 'powerlaw':
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:78, in get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#      74 def get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type='powerlaw'):
#      75     """
#      76     Get dynamics chain in right shape.
#      77     """
# ---> 78     samples_mcmc = np.loadtxt(
#      79         '../dynamics_chains/kcwi_dynamics_chain_{}_{}_{}_{}_{}_nl.txt'.format(
#      80             software, aperture_type, anisotropy_model, str(is_spherical), lens_model_type
#      81         )
#      82     )
#      84     n_params = samples_mcmc.shape[1]
#      86     n_walkers = walker_ratio * n_params
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#    1044     line_iter = iter(fh)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../dynamics_chains/kcwi_dynamics_chain_jampy_ifu_constant_False_composite_nl.txt not found.

# %%
0.3/299. * 100
# Out:
# 0.1003344481605351

# %%
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'ifu'], 
          ['constant', 'constant'], 
          [False, True], 
          ['powerlaw', 'powerlaw'], 
          burnin=-50, 
          legend_labels=[r'aaxisymmetric', r'spherical'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/axisymmetric_vs_spherical_compare.pdf',
          font_scale=1.2,
          select_indices=[-4, -2, -1]
         )
# Out:
# (2400, 8) 8
# Removed no burn in
# (2400, 8) 8
# Removed no burn in

# %%
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'single_slit'], 
          ['Osipkov-Merritt', 'Osipkov-Merritt'], 
          [True, True], 
          ['powerlaw', 'powerlaw'], 
          burnin=-50, 
          legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
          font_scale=1.2,
          select_indices=[-4, -2, -1]
         )
# Out:
# (2400, 8) 8
# Removed no burn in
# (2400, 8) 8
# Removed no burn in

# %%
print(get_bic('jampy', 'ifu', 'constant', False, 'powerlaw', burnin=-2))
print(get_bic('jampy', 'ifu', 'constant', False, 'composite', burnin=-2))
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 164.674279578871
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [20], line 2
#       1 print(get_bic('jampy', 'ifu', 'constant', False, 'powerlaw', burnin=-2))
# ----> 2 print(get_bic('jampy', 'ifu', 'constant', False, 'composite', burnin=-2))
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:359, in get_bic(software, aperture_type, anisotropy_model, is_spherical, lens_model_type, burnin)
#     348 """
#     349 """
#     350 likelihood_class = KinematicLikelihood(lens_model_type=lens_model_type,
#     351                                        software=software,
#     352                                        anisotropy_model=anisotropy_model,
#    (...)
#     356                                        mpi=False
#     357                                        )
# --> 359 params = get_most_likely_value(software, aperture_type, anisotropy_model, is_spherical,
#     360                                lens_model_type, burnin)
#     361 np.random.seed(2)
#     362 log_likelihood = likelihood_class.get_log_likelihood(params)
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:294, in get_most_likely_value(software, aperture_type, anisotropy_model, is_spherical, lens_model_type, burnin)
#     290 def get_most_likely_value(software, aperture_type, anisotropy_model, is_spherical,
#     291                           lens_model_type='powerlaw', burnin=-100):
#     292     """
#     293     """
# --> 294     chain = get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#     296     return np.mean(chain[:, burnin:, :].reshape((-1, chain.shape[-1])),
#     297                    axis=0)
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:78, in get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#      74 def get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type='powerlaw'):
#      75     """
#      76     Get dynamics chain in right shape.
#      77     """
# ---> 78     samples_mcmc = np.loadtxt(
#      79         '../dynamics_chains/kcwi_dynamics_chain_{}_{}_{}_{}_{}_nl.txt'.format(
#      80             software, aperture_type, anisotropy_model, str(is_spherical), lens_model_type
#      81         )
#      82     )
#      84     n_params = samples_mcmc.shape[1]
#      86     n_walkers = walker_ratio * n_params
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#    1044     line_iter = iter(fh)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../dynamics_chains/kcwi_dynamics_chain_jampy_ifu_constant_False_composite_nl.txt not found.

# %%
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'single_slit'], 
          ['constant', 'constant'], 
          [False, False], 
          ['powerlaw', 'powerlaw'], 
          burnin=-50, 
          legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
          font_scale=1.2,
          select_indices=[-4, -2, -1]
         )
# Out:
# (2400, 8) 8
# Removed no burn in
# (2400, 8) 8
# Removed no burn in

# %%
plot_dist(['galkin', 'galkin'], 
          ['ifu', 'single_slit'], 
          ['constant', 'constant'], 
          [True, True], 
          ['powerlaw', 'powerlaw'], 
          burnin=-50, 
          legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
          font_scale=1.2,
          select_indices=[-4, -2, -1]
         )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 plot_dist(['galkin', 'galkin'],
#       2           ['ifu', 'single_slit'],
#       3           ['constant', 'constant'],
#       4           [True, True],
#       5           ['powerlaw', 'powerlaw'],
#       6           burnin=-50,
#       7           legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
#       8           ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
#       9           #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
#      10           font_scale=1.2,
#      11           select_indices=[-4, -2, -1]
#      12          )
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:250, in plot_dist(softwares, aperture_types, anisotropy_models, is_sphericals, lens_model_types, burnin, legend_labels, save_fig, ani_param_latex, font_scale, select_indices)
#     246 mc_samples_list = []
#     248 for s, a, ani, sph, model in zip(softwares, aperture_types,
#     249                                  anisotropy_models, is_sphericals, lens_model_types):
# --> 250     mc_samples_list.append(get_getdist_samples(s, a, ani, sph, model, burnin=burnin,
#     251                                                latex_labels=latex_labels, select_indices=select_indices))
#     253 g = plots.getSubplotPlotter(subplot_size=2.2)
#     254 g.settings.lw_contour = 1.
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:204, in get_getdist_samples(software, aperture_type, anisotropy_model, is_spherical, lens_model_type, burnin, latex_labels, select_indices)
#     201     if latex_labels is None:
#     202         latex_labels = latex_labels_composite
# --> 204 chain = get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#     206 chain = chain[:, burnin:, :].reshape((-1, chain.shape[-1]))
#     207 if lens_model_type == 'powerlaw':
#
# File ~/Research/RXJ1131_KCWI/RXJ1131_KCWI_kinematics/plot_util.py:78, in get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type)
#      74 def get_chain(software, aperture_type, anisotropy_model, is_spherical, lens_model_type='powerlaw'):
#      75     """
#      76     Get dynamics chain in right shape.
#      77     """
# ---> 78     samples_mcmc = np.loadtxt(
#      79         '../dynamics_chains/kcwi_dynamics_chain_{}_{}_{}_{}_{}_nl.txt'.format(
#      80             software, aperture_type, anisotropy_model, str(is_spherical), lens_model_type
#      81         )
#      82     )
#      84     n_params = samples_mcmc.shape[1]
#      86     n_walkers = walker_ratio * n_params
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/npyio.py:1042, in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1040     fname = os_fspath(fname)
#    1041 if _is_string_like(fname):
# -> 1042     fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1043     fencoding = getattr(fh, 'encoding', 'latin1')
#    1044     line_iter = iter(fh)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File ~/miniforge3/lib/python3.9/site-packages/numpy/lib/_datasource.py:532, in DataSource.open(self, path, mode, encoding, newline)
#     529     return _file_openers[ext](found, mode=mode,
#     530                               encoding=encoding, newline=newline)
#     531 else:
# --> 532     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: ../dynamics_chains/kcwi_dynamics_chain_galkin_ifu_constant_True_powerlaw_nl.txt not found.

# %% [raw]
# print('power law:')
# plot_mcmc_trace('jampy', 'ifu', 'constant', False, 'powerlaw');
# print('composite:')
# plot_mcmc_trace('jampy', 'ifu', 'constant', False, 'composite');

# %% [raw]
# (1865.1468 - 1893.7850) / 1865.1468, (1865.1468 - 1893.7850) / np.sqrt(96.5615**2+124.0202**2) # ± 96.5615, 124.0202

# %% [raw]
# (1865.1468*0.9730 - 1893.7850*0.9072) / 1865.1468/0.9730
# #0.9072 ± 0.0532 , 0.9730 ± 0.0733
