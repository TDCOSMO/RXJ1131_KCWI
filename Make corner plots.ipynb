# %%
from plot_util import *

# %%
savefig = True

# %%
import palettable
import matplotlib.colors as colors

pf.set_fontscale(1.6)

# cmap = palettable.cubehelix.perceptual_rainbow_16.mpl_colormap

vmax, vmin = 365, 55
mid = 265 #(vmax + vmin) / 2.
f = 25


def _forward(x):
    return np.arctan((x - mid)/f)


def _inverse(x):
    return np.tan(x)*f + mid


norm = colors.FuncNorm((_forward, _inverse), vmin=vmin, vmax=vmax)


fig, axes = plot_residual('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', shape='oblate',
                          burnin=-2, 
                          cmap='viridis', vmax=vmax, vmin=vmin, norm=norm
                         );

# ax.set_xticks([])
# ax.set_yticks([])

# ax.set_title('')

if savefig:
    fig.savefig('/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/jampy_constant_elliptical.pdf', 
                bbox_inches='tight'
               )
    
fig;
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# reduced chi^2: 1.02
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`

# %% [markdown]
# ## oblate vs prolate

# %%
plot_dist(['jampy', 'jampy', 'jampy'][:2], 
          ['ifu', 'ifu', 'ifu'][:2], 
          ['constant', 'constant', 'constant'][:2], 
          ['axisymmetric']*2, 
          ['powerlaw']*2, 
          shapes=['oblate', 'prolate'],
          #oblate_fractions=[0.17],
          burnin=-50, 
          legend_labels=[r'prolate', #r'stepwise constant $\beta$ with free breakpoint', 
                         r'oblate', #r'stepwise constant $\beta$ with free breakpoint', 
                        ][:2],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}', 
                           '(\\sigma_{\\theta}/\\sigma_{r})_{\\rm outer}', "r_{\\rm break}\ ( '' )"][:2],
          select_indices=[[0, 1, 2, 3, 4, 5, 6, 7], [0, 1, 2, 3, 4, 5, 6, 7], [0, 1, 2, 3, 5, 6, 7]][:2],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/pl_axisymmetric_jam_oblate_vs_prolate.pdf' if savefig else None,
          font_scale=1.7, blind=True, print_difference=True
         )
# Out:
# (2400, 8) 8
# Removed no burn in
# (2400, 8) 8
# Removed no burn in
# Difference: -3.54%, -0.40 sigma
# WARNING:root:2D kernel density bandwidth optimizer failed for q, ani_param_1. Using fallback width: f(a) and f(b) must have different signs

# %% [markdown]
# ## anisotropy profiles

# %%
plot_dist(['jampy', 'jampy', 'jampy'][:3], 
          ['ifu', 'ifu', 'ifu'][:3], 
          ['free_step', 'step', 'constant'][:3], 
          ['axisymmetric']*3, 
          ['powerlaw']*3,
          oblate_fractions=[0.82]*3,
          burnin=-50, 
          legend_labels=[r'stepwise constant $\beta$ with free breakpoint', 
                         r'stepwise constant $\beta$', 
                         r'constant $\beta$'][:3],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}', 
                           '(\\sigma_{\\theta}/\\sigma_{r})_{\\rm outer}', "r_{\\rm break}\ ( '' )"][:3],
          select_indices=[[0, 1, 2, 3, 5, 6, 7, 8, 9], [0, 1, 2, 3, 5, 6, 7, 8], [0, 1, 2, 3, 5, 6, 7]],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/anisotropy_compare_axisymmetric_jam.pdf' if savefig else None,
          font_scale=1.7, blind=True, print_difference=True
         )
# Out:
# (3000, 10) (3000, 10) (3000, 10) 0.82
# (3000, 10) 10
# Removed no burn in
# (2700, 9) (2700, 9) (2700, 9) 0.82
# (2700, 9) 9
# Removed no burn in
# Difference: 3.20%, 0.25 sigma
# (2400, 8) (2400, 8) (2399, 8) 0.82
# (2399, 8) 8
# Removed no burn in
# Difference: -1.39%, -0.14 sigma
# WARNING:root:2D kernel density bandwidth optimizer failed for q, inclination. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for q, ani_param_1. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for inclination, lamda. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for inclination, ani_param_3. Using fallback width: f(a) and f(b) must have different signs
# WARNING:root:2D kernel density bandwidth optimizer failed for ani_param_2, ani_param_3. Using fallback width: f(a) and f(b) must have different signs

# %%
1 - 1.5**2
# Out:
# -1.25

# %%
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', 15, 'oblate', burnin=-100))
print(get_bic('jampy', 'ifu', 'step', 'axisymmetric', 'powerlaw', 15, 'oblate', burnin=-100))
print(get_bic('jampy', 'ifu', 'free_step', 'axisymmetric', 'powerlaw', 15, 'oblate', burnin=-100))
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 161.2453042660473
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 164.96273251215058
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 170.47021961167638

# %%
(161.2453042660473 - 164.96273251215058), 161.2453042660473 - 170.47021961167638
# Out:
# (-3.7174282461032817, -9.224915345629086)

# %%
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', 15, 'prolate', burnin=-100))
print(get_bic('jampy', 'ifu', 'step', 'axisymmetric', 'powerlaw', 15, 'prolate', burnin=-100))
print(get_bic('jampy', 'ifu', 'free_step', 'axisymmetric', 'powerlaw', 15, 'prolate', burnin=-100))
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 161.9105398463078
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 165.53485031518738
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 171.515915641664

# %% [markdown]
# # power-law model

# %%
plot_dist(['jampy'], 
          ['ifu'], 
          ['constant'], 
          ['axisymmetric'], 
          ['powerlaw'], 
          oblate_fractions=[0.82],
          burnin=-400, 
          legend_labels=[r'Power-law mass model with constant $\beta$ profile'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/pl_axisymmetric_jam.pdf' if savefig else None,
          select_indices=[[0, 1, 2, 3, 4, 6, 7]],
          font_scale=1.7, blind=True
         )
# Out:
# (19200, 8) (19200, 8) (19199, 8) 0.82
# (19199, 8) 8
# Removed no burn in

# %% [markdown]
# # composite model

# %%
plot_dist(['jampy'], 
          ['ifu'], 
          ['constant'], 
          ['axisymmetric'], 
          ['composite'], 
          oblate_fractions=[0.82],
          burnin=-200, 
          legend_labels=[r'composite mass model with constant $\beta$ profile'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_axisymmetric_jam.pdf' if savefig else None,
          select_indices=[[0, 1, 2, 3, 4, 6, 7, 8]],
          font_scale=1.7, blind=True
         )
# Out:
# (10800, 9) (10800, 9) (10800, 9) 0.82
# (10800, 9) 9
# Removed no burn in

# %%
plot_dist(['jampy']*2, 
          ['ifu']*2, 
          ['constant']*2, 
          ['axisymmetric']*2, 
          ['powerlaw', 'composite'], 
          oblate_fractions=[0.82]*2,
          burnin=-200, 
          legend_labels=[r'power-law mass model', r'composite mass model'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/comp_vs_pl_axisymmetric_jam.pdf' if savefig else None,
          font_scale=1.2,
          select_indices=[[-4, -2, -1], [-4, -2, -1]], blind=True, print_difference=True
         )
# Out:
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# (10800, 9) (10800, 9) (10800, 9) 0.82
# (10800, 9) 9
# Removed no burn in
# Difference: -2.12%, -0.27 sigma

# %%
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'ifu'], 
          ['constant', 'constant'], 
          ['axisymmetric', 'axisymmetric'], 
          ['powerlaw', 'powerlaw'],
          snrs=[15, 15],
          shapes=['oblate', 'prolate'],
          burnin=-200, 
          legend_labels=[r'axisymmetric oblate', r'axisymmetric prolate'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/prolate_vs_oblate_compare.pdf' if savefig else None,
          font_scale=1.2,
          select_indices=[[-4, -2, -1]]*2, blind=True, print_difference=True
         )
# Out:
# (9600, 8) 8
# Removed no burn in
# (9600, 8) 8
# Removed no burn in
# Difference: -2.64%, -0.28 sigma

# %%
20 / 323 * 293
# Out:
# 18.142414860681114

# %%
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'ifu'], 
          ['constant', 'constant'], 
          ['axisymmetric', 'spherical'], 
          ['powerlaw', 'powerlaw'],
          oblate_fractions=[0.82, None],
          burnin=-200, 
          legend_labels=[r'axisymmetric', r'spherical'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/axisymmetric_vs_spherical_compare.pdf' if savefig else None,
          font_scale=1.2,
          select_indices=[[-4, -2, -1]]*2, blind=True, print_difference=True
         )
# Out:
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# (9600, 8) 8
# Removed no burn in
# Difference: -4.48%, -0.57 sigma

# %%
# # OM anisotropy
# plot_dist(['jampy', 'jampy'], 
#           ['ifu', 'single_slit'], 
#           ['om', 'om'], 
#           ['spherical', 'spherical'], 
#           ['powerlaw', 'powerlaw'], 
#           oblate_fractions=[.80, .80],
#           burnin=-50, 
#           legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
#           ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
#           save_fig=None, #'/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf' if savefig else None,
#           font_scale=1.2,
#           select_indices=[[-4, -2, -1]]*2, blind=True, print_difference=True
#          )

# %%
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', 15, 'oblate', burnin=-200))
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', 15, 'prolate', burnin=-200))
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 161.2453042660473
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 161.9105398463078

# %%
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'powerlaw', 15, 'oblate', burnin=-200))
print(get_bic('jampy', 'ifu', 'constant', 'axisymmetric', 'composite', 15, 'oblate', burnin=-200))
# Out:
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 161.2453042660473
# Residuals > 10%: Change `inner_slope` or `outer_slope` or increase `ngauss`
# 166.40482882272593

# %%
np.exp(-(166.40482882272593 - 161.2453042660473)/2.), (166.40482882272593 - 161.2453042660473)
# Out:
# (0.07579201928614274, 5.159524556678633)

# %%
pf.set_fontscale(1.6)

plot_dist(['jampy', 'jampy'], 
          ['ifu', 'single_slit'], 
          ['constant', 'constant'], 
          ['axisymmetric', 'axisymmetric'], 
          ['powerlaw', 'powerlaw'], 
          oblate_fractions=[0.82, 0.82],
          burnin=-200, 
          legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
          font_scale=1.2,
          select_indices=[[-4, -2, -1]]*2, print_difference=True
         )
# Out:
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# D uncertainty 0.06
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# Difference: 3.88%, 0.25 sigma, D uncertainty: 0.14

# %% [markdown]
# ## SNR compare

# %%
# OM anisotropy
plot_dist(['jampy', 'jampy'], 
          ['ifu', 'ifu'], 
          ['constant', 'constant'], 
          ['axisymmetric', 'axisymmetric'], 
          ['powerlaw', 'powerlaw'], 
          oblate_fractions=[.82, .82],
          snrs=[15, 13],
          burnin=-200, 
          legend_labels=[r'Target SNR per bin $\approx$ 15', r'Target SNR per bin $\approx$ 13'],
          ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
          save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/snr_compare.pdf' if savefig else None,
          font_scale=1.2,
          select_indices=[[-4, -2, -1]]*2, blind=True, print_difference=True
         )
# Out:
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# (9600, 8) (9600, 8) (9599, 8) 0.82
# (9599, 8) 8
# Removed no burn in
# Difference: -0.12%, -0.01 sigma

# %% [raw]
# plot_dist(['galkin', 'galkin'],
#           ['ifu', 'single_slit'],
#           ['constant', 'constant'],
#           ['spherical', 'spherical'],
#           ['powerlaw', 'powerlaw'],
#           burnin=-50,
#           legend_labels=[r'spatially resolved velocity dispersion', r'integrated velocity dispersion'],
#           ani_param_latex=['\\sigma_{\\theta}/\\sigma_{r}'],
#           #save_fig='/Users/ajshajib/Dropbox/Papers_Proposals/rxj1131_kcwi/figures/ifu_vs_slit_compare.pdf',
#           font_scale=1.2,
#           select_indices=[-4, -2, -1]
#          )

# %% [raw]
# print('power law:')
# plot_mcmc_trace('jampy', 'ifu', 'constant', False, 'powerlaw');
# print('composite:')
# plot_mcmc_trace('jampy', 'ifu', 'constant', False, 'composite');

# %% [raw]
# (1865.1468 - 1893.7850) / 1865.1468, (1865.1468 - 1893.7850) / np.sqrt(96.5615**2+124.0202**2) # ± 96.5615, 124.0202

# %% [raw]
# (1865.1468*0.9730 - 1893.7850*0.9072) / 1865.1468/0.9730
# #0.9072 ± 0.0532 , 0.9730 ± 0.0733
